# %% [markdown]
# <a href="https://colab.research.google.com/github/kuroko-017/-Computational-Thinking-and-Programming-Design/blob/master/%E8%BF%B4%E5%9C%88Week15_A108260039_%E9%99%B3%E5%9E%A3%E5%9D%87.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=1

while n<5:
  print("變數n是",n)
  n=n+1

print("Finished")
# Out:
# 變數n是 1
# 變數n是 2
# 變數n是 3
# 變數n是 4
# Finished

# %%
x=0
while x<10:
  print("hello")
  x=x+1
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello

# %%
x=0
while x<1000:
  print("hello")
  x=x+1
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# ...

# %%
times=0
while times <10:
  times=times+1
  print("這是第",times,"次的hello")
# Out:
# 這是第 1 次的hello
# 這是第 2 次的hello
# 這是第 3 次的hello
# 這是第 4 次的hello
# 這是第 5 次的hello
# 這是第 6 次的hello
# 這是第 7 次的hello
# 這是第 8 次的hello
# 這是第 9 次的hello
# 這是第 10 次的hello

# %%
x=0
result=0

while x<10:
  x=x+1
  result=result+x

print("答案是:",result)
# Out:
# 答案是: 55

# %%
x=0
result=0

while result <=50:
  x=x+1
  result=result+x

print("最後加的x是",x)
# Out:
# 最後加的x是 10

# %%
sum=0
x=1
while x<11:
  sum=sum+x
  x=x+2

print("1+3+5+7+9=",sum)
# Out:
# 1+3+5+7+9= 25

# %%
sum=0
i=0

while sum <=1000:
  i=i+1
  sum+=i*i
print("最小的值為",i)
# Out:
# 最小的值為 14

# %%
i=1
while(i<6):
  print(i)
  if i==3:
    break
  i+=1
# Out:
# 1
# 2
# 3

# %%
i=1
while(i<7):
  i+=1
  if i==4:
    continue
  print(i)
# Out:
# 2
# 3
# 5
# 6
# 7

# %%
i=1
while(i<6):
  print(i)
  if i==6:
    break
  i+=1
# Out:
# 1
# 2
# 3
# 4
# 5
